# %%
import pandas as pd
import os

loading_student_data = os.path.join("Resources",
                                    "students_complete.csv")

reading_student_data = pd.read_csv(loading_student_data)
reading_student_data
# Out:
#        Student ID       student_name gender grade         school_name  \
# 0               0       Paul Bradley      M   9th   Huang High School
# 1               1       Victor Smith      M  12th   Huang High School
# 2               2    Kevin Rodriguez      M  12th   Huang High School
# 3               3  Dr. Richard Scott      M  12th   Huang High School
# 4               4         Bonnie Ray      F   9th   Huang High School
# ...           ...                ...    ...   ...                 ...
# 39165       39165       Donna Howard      F  12th  Thomas High School
# 39166       39166          Dawn Bell      F  10th  Thomas High School
# 39167       39167     Rebecca Tanner      F   9th  Thomas High School
# 39168       39168       Desiree Kidd      F  10th  Thomas High School
# 39169       39169    Carolyn Jackson      F  11th  Thomas High School
#
#        reading_score  math_score
# 0                 66          79
# 1                 94          61
# ...

# %%
student_name_list = reading_student_data["student_name"].tolist()
student_name_list
# Out:
# ['Paul Bradley',
#  'Victor Smith',
#  'Kevin Rodriguez',
#  'Dr. Richard Scott',
#  'Bonnie Ray',
#  'Bryan Miranda',
#  'Sheena Carter',
#  'Nicole Baker',
#  'Michael Roth',
#  'Matthew Greene',
#  'Andrew Alexander',
#  'Daniel Cooper',
#  'Brittney Walker',
#  'William Long',
#  'Tammy Hebert',
#  'Dr. Jordan Carson',
#  'Donald Zamora',
#  'Kimberly Santiago',
#  'Kevin Stevens',
#  'Brandi Lyons',
#  'Lisa Davis',
#  'Kristen Lopez',
#  'Kimberly Stewart',
#  'Christopher Parker',
#  'Chelsea Griffith',
#  'Cesar Morris',
#  'Melanie Decker',
#  'Tracey Oconnor',
#  'Kelly James',
#  'Nicole Brown',
#  'Bobby Harris',
#  'Brian Fernandez',
#  'Candace Phelps',
#  'Amy Gonzalez',
#  'Steven Green',
#  'Benjamin Carlson',
#  'Kevin Bailey',
#  'Jesse Newton',
#  'Kimberly Mercado',
#  'Gregory Roberts',
#  'Matthew Mayer',
#  'Jennifer Parks',
#  'John Carlson',
#  'Megan Roberts',
#  'Debra Flores',
#  'Heidi Jackson',
#  'Denise Bradford',
#  'Ellen Brown',
#  'Amy Perkins',
# ...

# %%
name_list_of_len3plus = []
for name in student_name_list:
    name_split = name.split()
    name_length = len(name_split)
    print(f'Name: {name_split}; length: {name_length}')
# Out:
# Name: ['Paul', 'Bradley']; length: 2
# Name: ['Victor', 'Smith']; length: 2
# Name: ['Kevin', 'Rodriguez']; length: 2
# Name: ['Dr.', 'Richard', 'Scott']; length: 3
# Name: ['Bonnie', 'Ray']; length: 2
# Name: ['Bryan', 'Miranda']; length: 2
# Name: ['Sheena', 'Carter']; length: 2
# Name: ['Nicole', 'Baker']; length: 2
# Name: ['Michael', 'Roth']; length: 2
# Name: ['Matthew', 'Greene']; length: 2
# Name: ['Andrew', 'Alexander']; length: 2
# Name: ['Daniel', 'Cooper']; length: 2
# Name: ['Brittney', 'Walker']; length: 2
# Name: ['William', 'Long']; length: 2
# Name: ['Tammy', 'Hebert']; length: 2
# Name: ['Dr.', 'Jordan', 'Carson']; length: 3
# Name: ['Donald', 'Zamora']; length: 2
# Name: ['Kimberly', 'Santiago']; length: 2
# Name: ['Kevin', 'Stevens']; length: 2
# Name: ['Brandi', 'Lyons']; length: 2
# Name: ['Lisa', 'Davis']; length: 2
# Name: ['Kristen', 'Lopez']; length: 2
# Name: ['Kimberly', 'Stewart']; length: 2
# Name: ['Christopher', 'Parker']; length: 2
# ...

# %%
name_list_of_len3plus = []
for name in student_name_list:
    name_split = name.split()
    name_length = len(name_split)
    if name_length >= 3:
        name_list_of_len3plus.append(name)
        # NOTE hat having print(name_list_of_len3plus) here will result in printing a new line each time there
        # is a new name_split with len greater than 3
    # NOTE that having print(name_list_of_len3plus) here will result in printing a new line for each iteration
print(name_list_of_len3plus)
# Out:
# ['Dr. Richard Scott', 'Dr. Jordan Carson', 'Madeline Snyder MD', 'Mr. Dylan Taylor MD', 'Dr. Scott Gill', 'Miss Madison Everett', 'Virginia Ramirez MD', 'Joseph Morales III', 'Angela Perkins DVM', 'Heather Allen MD', 'Luke Lowery MD', 'Dr. Larry Hines', 'Emily Cardenas MD', 'Mrs. Elizabeth Espinoza DDS', 'Mrs. Lisa Becker', 'Mr. Travis Young', 'Paula Fernandez DVM', 'Dr. Xavier Bell II', 'Andrew Hanson MD', 'Mr. Roberto Wright MD', 'Mr. Dale Miller', 'Mary Gonzalez DDS', 'Mrs. Cindy Brown', 'James White MD', 'Donald Gill DDS', 'Mrs. Catherine Williams MD', 'Ashley Caldwell MD', 'Mr. Jared Campbell', 'Michael Moreno PhD', 'Tara Parker MD', 'Shawn Williams DVM', 'Dr. Alicia Martinez', 'Mr. Timothy Anderson', 'Mrs. Paula Lee', 'Mr. Elijah Hall', 'Mr. Raymond Stone', 'John Dickerson MD', 'Mr. Alex Franklin', 'Mrs. Jessica Dunn', 'Mr. Michael Stevenson', 'Jason Jones DDS', 'Adriana Wade MD', 'Erica Hurley MD', 'Dr. Garrett Wright', 'Mr. James Allen', 'Mr. Timothy Harper MD', 'Dale Brown M
# ...

# %%
len(name_list_of_len3plus)
# Out:
# 1531

# %%
# PREFIX --> [0]
prefix_list = []

for index in name_list_of_len3plus:
    if len(index.split()[0]) <= 4:
        # index.split() --> list of index AFTER split
        # if the length of the individual split is 4 or greater then add the first
        # position of the split into the new list made --> NOTE 4 because the longest
        # known prefix in the list is 4
        prefix_list.append(index.split()[0])

prefix_list
# Out:
# ['Dr.',
#  'Dr.',
#  'Mr.',
#  'Dr.',
#  'Miss',
#  'Luke',
#  'Dr.',
#  'Mrs.',
#  'Mrs.',
#  'Mr.',
#  'Dr.',
#  'Mr.',
#  'Mr.',
#  'Mary',
#  'Mrs.',
#  'Mrs.',
#  'Mr.',
#  'Tara',
#  'Dr.',
#  'Mr.',
#  'Mrs.',
#  'Mr.',
#  'Mr.',
#  'John',
#  'Mr.',
#  'Mrs.',
#  'Mr.',
#  'Dr.',
#  'Mr.',
#  'Mr.',
#  'Dale',
#  'Dr.',
#  'Dr.',
#  'Dr.',
#  'Ms.',
#  'Dr.',
#  'Dr.',
#  'Mr.',
#  'Mrs.',
#  'Amy',
#  'Mr.',
#  'Dr.',
#  'Mr.',
#  'Mr.',
#  'Mrs.',
#  'Mrs.',
#  'Mr.',
#  'Lisa',
#  'Mr.',
#  'Dr.',
#  'Mr.',
#  'Mr.',
#  'Mr.',
#  'Dr.',
#  'Mr.',
#  'Mark',
#  'Mrs.',
#  'Dr.',
#  'Dr.',
#  'Miss',
#  'Mr.',
#  'Miss',
#  'Mr.',
#  'Mrs.',
#  'Mr.',
#  'Mrs.',
#  'Mr.',
#  'Mr.',
#  'Mr.',
#  'Dr.',
#  'Dr.',
#  'Miss',
#  'Mr.',
#  'Mrs.',
#  'Mr.',
#  'Tara',
#  'Dr.',
#  'Mr.',
#  'Cody',
#  'Mr.',
#  'Dr.',
#  'Mr.',
#  'Ms.',
#  'Dr.',
#  'Mr.',
#  'Mrs.',
#  'Sara',
#  'Mr.',
#  'Mrs.',
#  'Dr.',
#  'Mr.',
#  'Dr.',
#  'Mr.',
#  'Mrs.',
#  'Mr.',
#  'Mr.',
#  'Mr.',
# ...

# %%
# SUFFIX --> [-1]
suffix_list = []

for index in name_list_of_len3plus:
    if len(index.split()[-1]) <= 3:
        # if the length of the split is 3 or greater then add the last position of the
        # split into the new list made --> NOTE 3 because the longest known suffix in 
        # the list is 3
        suffix_list.append(index.split()[-1])

suffix_list
# Out:
# ['MD',
#  'MD',
#  'MD',
#  'III',
#  'DVM',
#  'MD',
#  'MD',
#  'MD',
#  'DDS',
#  'DVM',
#  'II',
#  'MD',
#  'MD',
#  'DDS',
#  'MD',
#  'DDS',
#  'MD',
#  'MD',
#  'PhD',
#  'MD',
#  'DVM',
#  'Lee',
#  'MD',
#  'DDS',
#  'MD',
#  'MD',
#  'MD',
#  'MD',
#  'MD',
#  'MD',
#  'DDS',
#  'Jr.',
#  'DVM',
#  'MD',
#  'MD',
#  'PhD',
#  'IV',
#  'MD',
#  'DDS',
#  'DDS',
#  'DDS',
#  'MD',
#  'DDS',
#  'MD',
#  'DVM',
#  'IV',
#  'MD',
#  'DDS',
#  'MD',
#  'MD',
#  'DVM',
#  'Jr.',
#  'MD',
#  'PhD',
#  'II',
#  'MD',
#  'DDS',
#  'DDS',
#  'DDS',
#  'Jr.',
#  'III',
#  'MD',
#  'MD',
#  'MD',
#  'DDS',
#  'Jr.',
#  'DDS',
#  'DVM',
#  'DDS',
#  'DVM',
#  'MD',
#  'DDS',
#  'PhD',
#  'DDS',
#  'DDS',
#  'Jr.',
#  'Jr.',
#  'DVM',
#  'DDS',
#  'MD',
#  'MD',
#  'DVM',
#  'DDS',
#  'DVM',
#  'Jr.',
#  'MD',
#  'Jr.',
#  'MD',
#  'PhD',
#  'PhD',
#  'DDS',
#  'MD',
#  'DDS',
#  'DVM',
#  'Cox',
#  'DVM',
#  'MD',
#  'Jr.',
#  'MD',
#  'DDS',
#  'MD',
#  'MD',
#  'DDS',
#  'DDS',
# ...

# %%
set(prefix_list)
    # obtains the unique items in prefix_list --> eliminates duplicates
# Out:
# {'Adam',
#  'Amy',
#  'Anna',
#  'Anne',
#  'Carl',
#  'Chad',
#  'Cody',
#  'Cory',
#  'Dale',
#  'Dana',
#  'Dawn',
#  'Dr.',
#  'Emma',
#  'Eric',
#  'Erik',
#  'Erin',
#  'Gail',
#  'Gary',
#  'Gina',
#  'Greg',
#  'Ian',
#  'Jill',
#  'Jodi',
#  'Joe',
#  'John',
#  'Jon',
#  'Jose',
#  'Judy',
#  'Kara',
#  'Kari',
#  'Kim',
#  'Kyle',
#  'Leah',
#  'Lisa',
#  'Lori',
#  'Luke',
#  'Lynn',
#  'Marc',
#  'Mark',
#  'Mary',
#  'Mike',
#  'Miss',
#  'Mr.',
#  'Mrs.',
#  'Ms.',
#  'Noah',
#  'Omar',
#  'Paul',
#  'Ruth',
#  'Ryan',
#  'Sara',
#  'Sean',
#  'Seth',
#  'Tara',
#  'Tina',
#  'Todd',
#  'Toni',
#  'Tony',
#  'Troy'}

# %%
set(suffix_list)
    # obtains the unique items in suffix_list --> eliminates duplicates
# Out:
# {'Cox',
#  'DDS',
#  'DVM',
#  'Day',
#  'II',
#  'III',
#  'IV',
#  'Jr.',
#  'Kim',
#  'Lee',
#  'Li',
#  'MD',
#  'PhD',
#  'Roy',
#  'V'}

# %%
prefix_and_suffix_list = ["Dr. ", "Mr. ","Ms. ", "Mrs. ", "Miss ", " MD", " DDS", " DVM", " PhD"]
    # NOTE that this list was manually completed based on the set of the prefix_list and suffix_list
    # NOTE that there are spaces to account for whitespaces once they are removed
    
for word in prefix_and_suffix_list:
    reading_student_data["student_name"] = reading_student_data["student_name"].str.replace(word,"")
reading_student_data
# Out:
# /Users/School/opt/anaconda3/envs/PythonData/lib/python3.7/site-packages/ipykernel_launcher.py:6: FutureWarning: The default value of regex will change from True to False in a future version.
#        Student ID     student_name gender grade         school_name  \
# 0               0     Paul Bradley      M   9th   Huang High School
# 1               1     Victor Smith      M  12th   Huang High School
# 2               2  Kevin Rodriguez      M  12th   Huang High School
# 3               3    Richard Scott      M  12th   Huang High School
# 4               4       Bonnie Ray      F   9th   Huang High School
# ...           ...              ...    ...   ...                 ...
# 39165       39165     Donna Howard      F  12th  Thomas High School
# 39166       39166        Dawn Bell      F  10th  Thomas High School
# 39167       39167   Rebecca Tanner      F   9th  Thomas High School
# 39168       39168     Desiree Kidd      F  10th  Thomas High School
# ...

# %%
reading_student_data["student_name"].tolist()
# Out:
# ['Paul Bradley',
#  'Victor Smith',
#  'Kevin Rodriguez',
#  'Richard Scott',
#  'Bonnie Ray',
#  'Bryan Miranda',
#  'Sheena Carter',
#  'Nicole Baker',
#  'Michael Roth',
#  'Matthew Greene',
#  'Andrew Alexander',
#  'Daniel Cooper',
#  'Brittney Walker',
#  'William Long',
#  'Tammy Hebert',
#  'Jordan Carson',
#  'Donald Zamora',
#  'Kimberly Santiago',
#  'Kevin Stevens',
#  'Brandi Lyons',
#  'Lisa Davis',
#  'Kristen Lopez',
#  'Kimberly Stewart',
#  'Christopher Parker',
#  'Chelsea Griffith',
#  'Cesar Morris',
#  'Melanie Decker',
#  'Tracey Oconnor',
#  'Kelly James',
#  'Nicole Brown',
#  'Bobby Harris',
#  'Brian Fernandez',
#  'Candace Phelps',
#  'Amy Gonzalez',
#  'Steven Green',
#  'Benjamin Carlson',
#  'Kevin Bailey',
#  'Jesse Newton',
#  'Kimberly Mercado',
#  'Gregory Roberts',
#  'Matthew Mayer',
#  'Jennifer Parks',
#  'John Carlson',
#  'Megan Roberts',
#  'Debra Flores',
#  'Heidi Jackson',
#  'Denise Bradford',
#  'Ellen Brown',
#  'Amy Perkins',
# ...

# %%
# Creating a list for student names with still a length of 3 or greater

semi_fixed_student_name = reading_student_data["student_name"].tolist()
semi_fixed_student_name_list = []
for name in semi_fixed_student_name:
    name_split = name.split()
    name_length = len(name_split)
    if name_length >= 3:
        semi_fixed_student_name_list.append(name)
print(f' {semi_fixed_student_name_list} \n with a total of {len(semi_fixed_student_name_list)}')
# Out:
#  ['Joseph Morales III', 'Xavier Bell II', 'David Miller Jr.', 'Reginald Garcia IV', 'Kevin Brown IV', 'William Washington Jr.', 'Juan Bryant II', 'Kenneth Paul Jr.', 'Scott Rivers III', 'Mark Myers Jr.', 'Michael Norton Jr.', 'Sean Pena Jr.', 'Cody Mueller Jr.', 'Mathew White Jr.', 'Jason Daugherty Jr.', 'Leonard Webster II', 'Michael Stein Jr.', 'Ryan Phillips Jr.', 'Allen Snyder Jr.', 'Calvin Williams Jr.', 'Ronald Torres Jr.', 'Gabriel Smith III', 'Brian Pitts Jr.', 'Bruce Thompson II', 'Jeremy Sanders II', 'Austin Johnson II', 'Bryan Conway Jr.', 'Ronald Moore II', 'Robert Garrison IV', 'William Gonzalez Jr.', 'Brian Matthews Jr.', 'Eric Richards Jr.', 'Kenneth Munoz Jr.', 'Jon Delgado Jr.', 'Andrew English Jr.', 'Raymond Cox Jr.', 'Jeffrey Mcclain Jr.', 'Brian Poole V', 'Jeffrey Kim II', 'Matthew Alexander Jr.', 'Kevin Reynolds Jr.', 'Jacob Skinner Jr.', 'Dennis Gibson Jr.', 'Jimmy Shea Jr.', 'James Reed Jr.', 'Jeffery Baker Jr.', 'Derrick Hughes III', 'Joshua Rivera Jr.', 'Timo
# ...
